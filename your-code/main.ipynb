# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib as mt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit= pd.read_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Labs\Semana 5\5.2-lab-matplotlib-seaborn\data\Fitbit2.csv')

# %%
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %%
mes=fitbit[['Calorie burned','Steps','Distance']].groupby(fitbit['Months']).mean()
mes
# Out:
#            Calorie burned         Steps   Distance
# Months
# April         3030.800000  13079.033333  11.190667
# August        2844.967742  11584.774194   9.059677
# December      2737.290323   8470.064516   7.460323
# February      2600.100000   8922.866667   7.143667
# January       2812.806452   9892.064516   7.912581
# July          2699.935484   9193.322581   8.695484
# June          2971.666667  12536.166667  10.881667
# March         2281.258065  10312.935484   9.184194
# May           2836.580645  10620.096774   8.799677
# November      2578.066667   9467.466667   7.927333
# October       2608.838710   8272.451613   6.570000
# September     2908.000000   9191.333333   7.836333

# %%
fitbit.describe().T
# Out:
#                             count          mean          std      min  \
# Calorie burned              367.0   2741.501362   916.307036  179.000
# Steps                       367.0  10121.588556  5594.836225    0.000
# Distance                    367.0      8.549128     3.409881    0.000
# Floors                      367.0     11.724796    10.337370    0.000
# Minutes Sedentary           367.0    563.934482   294.793145    1.002
# Minutes Lightly Active      367.0    236.405995    86.531376    0.000
# Minutes Fairly Active       367.0     26.163488    20.319456    0.000
# Minutes Very Active         367.0     35.722071    31.006682    0.000
# Activity Calories           367.0   2044.147139  2041.267168    0.000
# MinutesOfSleep              367.0    290.479564   154.752328    0.000
# MinutesOfBeingAwake         367.0     28.008174    18.541415    0.000
# NumberOfAwakings            367.0     16.196185    10.757622    0.000
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %% [markdown]
# # AVERAGE STEPS BY WORK_OR_WEEKEND
# # your code here

# %%
df= pd.DataFrame(fitbit.groupby(fitbit.Months_encoded).Steps.mean())

# %%
df
# Out:
#                        Steps
# Months_encoded
# 1                9892.064516
# 2                8922.866667
# 3               10312.935484
# 4               13079.033333
# 5               10620.096774
# 6               12536.166667
# 7                9193.322581
# 8               11584.774194
# 9                9191.333333
# 10               8272.451613
# 11               9467.466667
# 12               8470.064516

# %%
sns.barplot(x=df.index, y=df.Steps);

# %%
df1= pd.DataFrame(fitbit.groupby(fitbit.Work_or_Weekend).Steps.mean())
df1
# Out:
#                         Steps
# Work_or_Weekend
# 0                10064.238095
# 1                10144.572519

# %%
sns.barplot(x=df1.index, y=df1.Steps);

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

sns.scatterplot(data=fitbit,
                x='Steps', 
                y='Minutes Lightly Active');

# %%
sns.scatterplot(data=fitbit,
                x='Steps', 
                y='Minutes Very Active');

# %%
sns.scatterplot(data=fitbit,
                x='Steps', 
                y='Minutes Sedentary');

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic= pd.read_csv(r'C:\Users\Héctor\Documents\IRONHACK\DATA ANALIST\BOOTCAMP\Labs\Semana 5\5.2-lab-matplotlib-seaborn\data\titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
titanic.describe().T
# Out:
#               count        mean         std   min       25%       50%  \
# PassengerId  1309.0  655.000000  378.020061  1.00  328.0000  655.0000
# Survived      891.0    0.383838    0.486592  0.00    0.0000    0.0000
# Pclass       1309.0    2.294882    0.837836  1.00    2.0000    3.0000
# Age          1309.0   29.879186   13.448335  0.17   22.0000   28.5000
# SibSp        1309.0    0.498854    1.041658  0.00    0.0000    0.0000
# Parch        1309.0    0.385027    0.865560  0.00    0.0000    0.0000
# Fare         1309.0   33.281086   51.741500  0.00    7.8958   14.4542
#
#                  75%        max
# PassengerId  982.000  1309.0000
# Survived       1.000     1.0000
# Pclass         3.000     3.0000
# Age           37.000    80.0000
# SibSp          1.000     8.0000
# Parch          0.000     9.0000
# Fare          31.275   512.3292

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %% [markdown]
# NUMERICAL VARIABLES ARE:
# PassengerId
# Survived
# Pclass
# Age	1309.
# SibSp
# Parch
# Fare

# %% [markdown]
#  CATEGORICAL VARIABLES ARE:
#
#  Ticket
#  Cabin
#  Embarked
#  Name
#  Gender

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
mt.rcParams['figure.figsize']=(12, 6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(data=titanic.Age, bins= 160, kde=True);

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
from matplotlib import pyplot as plt
sns.set()

# %%
fig, ax = plt.subplots(1,3, sharex=True )
fig.suptitle('Age distribution by bins equal to 10, 20 and 50');
ax[0].set_title('Age distribution by 10')
ax[1].set_title('Age distribution by 20')
ax[2].set_title('Age distribution by 50')
sns.histplot(ax= ax[0], data=titanic.Age, bins= 10, kde=True);
sns.histplot(ax= ax[1], data=titanic.Age, bins= 20, kde=True);
sns.histplot(ax= ax[2], data=titanic.Age, bins= 50, kde=True);

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
When you create more bins the data changes into a more detaiiled plot. But when you check the kde the distribution remain the same.
"""
# Out:
# '\nyour comments here\nWhen you create more bins the data changes into a more detaiiled plot. But when you check the kde the distribution remain the same.\n'

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
df2=pd.DataFrame(titanic.Gender.value_counts())
df2
# Out:
#         Gender
# male       843
# female     466

# %%
# Method 2 - seaborn
sns.barplot(x=df2.index, y=df2.Gender);

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(titanic.Pclass);
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
df3=pd.DataFrame(titanic.Age.describe())
sns.violinplot(
            data=titanic.Age,
            showmeans=True
            );

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %% [markdown]
# """
#
# It told us that mean it is around 30, the median below 30.Also the 50 percent of the sample it is concentrated around 20-38 years old. The min is 0 and the max it is around 80
# """

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
df4=pd.DataFrame(titanic.Age.value_counts())

df4.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - seaborn
# your code here
corr=titanic.corr(method='pearson')
corr
sns.regplot(data= titanic, y='Fare', 
                x='Age')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
sns.set(style='white')     # estilo blanco


mascara=np.triu(np.ones_like(corr, dtype=bool))   # genera una mascara para tapar valores


cmap=sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores


sns.heatmap(corr,
            mask=mascara,
            cmap=cmap,
            vmax=1,
            center=0,
            square=True,
            linewidth=0.5,
            cbar_kws={'shrink': 0.5},
            annot=True
           );

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
The most related ones are the 2 negatives. between class and age, and between class and survived.
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
